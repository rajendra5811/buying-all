# %%
  from pyspark.sql.functions import *

# %% [markdown]
# # Establish Connection

# %%
spark.conf.set("fs.azure.account.key.cf22acc.dfs.core.windows.net","3oibNjTFSPd7b0DCBUHUhQj2jc5C5S0lVji/ekaBBNypxDUf2xteuP5gvvSA00Nfx0CT8k41uxBG+AStE+EpxA==")

# %%
filename= dbutils.fs.ls("abfss://bronze@cf22acc.dfs.core.windows.net/")[0].name
filename
# Out:
# 'data_8db436bb-59e0-4b21-aad7-39b0fae829f7_e3ab070d-1480-4326-9f7e-d74963e6c31c.parquet'

# %%
df = spark.read.parquet(f"abfss://bronze@cf22acc.dfs.core.windows.net/rawdata/{filename}")
df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df.printSchema()
#This is a Spark / Databricks display behavior issue, not a problem with your Parquet file
# Out:
# root
#  |-- OrderID: integer (nullable = true)
#  |-- OrderDate: date (nullable = true)
#  |-- CustomerID: integer (nullable = true)
#  |-- CustomerName: string (nullable = true)
#  |-- CustomerEmail: string (nullable = true)
#  |-- Country: string (nullable = true)
#  |-- ProductID: integer (nullable = true)
#  |-- ProductCategory: string (nullable = true)
#  |-- ProductName: string (nullable = true)
#  |-- Quantity: integer (nullable = true)
#  |-- UnitPrice: decimal(18,2) (nullable = true)
#  |-- TotalPrice: decimal(18,2) (nullable = true)
#  |-- SalesRegion: string (nullable = true)

# %% [markdown]
# # check datatypes

# %% [markdown]
# # convert to titlecase - initcap

# %%
df=df.withColumn("Country",initcap(col("Country")))
df=df.withColumn("ProductCategory",initcap(col("ProductCategory")))
df=df.withColumn("SalesRegion",initcap(col("SalesRegion")))
df=df.withColumn("CustomerName",initcap(col("CustomerName")))
df=df.withColumn("ProductName",initcap(col("ProductName")))
df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# # Remove rows where all of the values are missing

# %%
df=df.dropna(how='all')
df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# # Remove Duplicate Rows

# %%
df=df.dropDuplicates()
df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df.write.format('parquet').mode('overwrite').option("path",'abfss://bronze@cf22acc.dfs.core.windows.net/silverdata').save()
